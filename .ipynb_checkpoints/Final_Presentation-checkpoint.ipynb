# %% [markdown]
# # Medium Analytics
# ##### by  Harsha, Jenna, Shinu, and Jesse

# %% [markdown]
# ### Part 0: Check the robots.txt
# to see what you can scrape at: https://medium.com/robots.txt

# %% [markdown]
# ## Part 1: Sample - looking at a single page
# basic webpage accessing and scraping the top of the art topics page (without scrolling). Only about 10 articles. Was able to retrieve links

# %%
#imports
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

#the url topic (root url)
url = "https://medium.com/topic/art"

#requesting the url to get access to the page
r = requests.get(url)
#should be 200
print(r)

#parsing in the information
soup = BeautifulSoup(r.content, "html5lib")
# Out:
# <Response [200]>

# %%
#look at the html in nice format
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script>
#    !function(c,f){var t,o,i,e=[],r={passive:!0,capture:!0},n=new Date,a="pointerup",u="pointercancel";function p(n,e){t||(t=e,o=n,i=new Date,w(f),s())}function s(){0<=o&&o<i-n&&(e.forEach(function(n){n(o,t)}),e=[])}function l(n){if(n.cancelable){var e=(1e12<n.timeStamp?new Date:performance.now())-n.timeStamp;"pointerdown"==n.type?function(n,e){function t(){p(n,e),i()}function o(){i()}function i(){f(a,t,r),f(u,o,r)}c(a,t,r),c(u,o,r)}(e,n):p(e,n)

# %%
### REGEX ###
#example of link I want to get
'<a href="https://psiloveyou.xyz/remembering-the-terrible-cb7ebf24a6da?source=topic_page---------6------------------1"'

#Regex pattern to get html tags (want entire html)
#divs and labels were too confusing so this was the best/easiest way to get urls
pattern = 'href="(.{5,100}source=topic_page\-+\d\-+\d)'

#find all the htmls in the string using REGEX
result = re.findall(pattern, str(soup))
result[:5]
# Out:
# ['/@Rashmee/questions-still-linger-about-colonial-era-artefacts-18876e0e824?source=topic_page---------0------------------1',
#  '/@Rashmee/questions-still-linger-about-colonial-era-artefacts-18876e0e824?source=topic_page---------0------------------1',
#  '/@Rashmee/questions-still-linger-about-colonial-era-artefacts-18876e0e824?source=topic_page---------0------------------1',
#  '/@Rashmee?source=topic_page---------0------------------1',
#  '/@Rashmee/questions-still-linger-about-colonial-era-artefacts-18876e0e824?source=topic_page---------0------------------1',
#  '/@chrisjones_32882/reading-art-paul-klees-twittering-machine-e36b88609c58?source=topic_page---------1------------------1',
#  '/@chrisjones_32882/reading-art-paul-klees-twittering-machine-e36b88609c58?source=topic_page---------1------------------1',
#  '/@chrisjones_32882/reading-art-paul-klees-twittering-machine-e36b88609c58?source=topic_page---------1------------------1',
#  '/@chrisjones_32882?source=topic_page---------1------------------1',
#  '/@chrisjones_32882/reading-art-paul-klees-twittering-machine-e36b88609c58?source=topic_page---------1------------------1']

# %% [markdown]
# ## Part 2: Using Selenium to Scroll and Get all the URLs at once
# creating a new browser that will automatically scroll down the page for you. Using the developer tools it was noticed that "POST" calls were being made when the scroll down occurred, but no "GET" calls were made. Thus, since we could not use the GET calls, we decided to use the scroller instead.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
#opens a new browser to scroll down automatically
browser = webdriver.Chrome(executable_path = r"C:\Users\jesse\Downloads\chromedriver_win32\chromedriver.exe")
browser.get("https://medium.com/topic/politics")

# %%
#code based off of stackoverflow code #4
time.sleep(1)
elem = browser.find_element_by_tag_name("body")
pagedowns = 100000
while pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    pagedowns-=1
    
pages = browser.page_source

# %% [markdown]
# ## Part 3: Processing
# using the regex tested above, able to get html links from the browser object. Then we dropped duplicates and cleaned the links. Some of the processing is shown below:

# %%
#Regex pattern to get html tags
pattern = 'href="(.{5,100}source=topic_page\-+\d{1,5}\-+\d)'

#get all the html links based on the pattern
result = re.findall(pattern, pages)

#put into a series to process
html_links = pd.Series(result)

#export to csv for safekeeping
html_links.to_csv("htmls_politics.csv")
# Out:
# ['https://gen.medium.com/does-cutting-u-s-aid-help-or-hurt-central-america-55db640f2add?source=topic_page---------5109------------------1',
#  'https://gen.medium.com/does-cutting-u-s-aid-help-or-hurt-central-america-55db640f2add?source=topic_page---------5109------------------1',
#  '/@johnbwashington?source=topic_page---------5109------------------1',
#  'https://gen.medium.com/?source=topic_page---------5109------------------1',
#  'https://gen.medium.com/does-cutting-u-s-aid-help-or-hurt-central-america-55db640f2add?source=topic_page---------5109------------------1']

# %%
#using the saved csv
topic = pd.read_csv("htmls_politics.csv", index_col = 0, header = None)

#drop all the duplicates
htmls = topic.drop_duplicates().reset_index(drop=True)

# %%
#a look at some of the htmls... seems as though some are missing the "https:"
topics.head()
# Out:
# 0    https://arcdigital.media/trumps-trade-war-is-k...
# 1    /@maxburnswrites?source=topic_page---------0--...
# 2    https://arcdigital.media/?source=topic_page---...
# 3    /@fnfwriter?source=topic_page---------1-------...
# 4    /politically-speaking?source=topic_page-------...
# dtype: object

# %%
#just get the url column
htmls = htmls[1]

#there are some repeat html links, so getting rid of the repeats
clean_htmls = htmls[~htmls.str.contains(r"^.{2,30}\?source=topic")]

# %%
### ADD HTTP to some versus not others ###

#links with https already included (no user in url)
with_http = clean_htmls[clean_htmls.str.contains("https://")].reset_index(drop=True)

#links without https:
without_http = clean_htmls[~clean_htmls.str.contains("https://")].reset_index(drop=True)

# %%
#adding medium before in order to get the full url
urls = "https://medium.com" + without_http

# %%
#combine all the urls together
pd.concat([urls, with_http], ignore_index = True).tail()
# Out:
# 1679    https://magenta.as/legendary-cartoonist-ben-ka...
# 1680    https://timeline.com/hannah-wilke-labial-art-9...
# 1681    https://artplusmarketing.com/kathy-griffins-ar...
# 1682    https://medium.muz.li/why-gradients-are-the-ne...
# 1683    https://brightthemag.com/a-tale-of-two-artists...
# Name: 1, dtype: object

# %%
#cleaned htmls (entire html should work)
urls.to_csv("cleaned_htmls.csv")

# %% [markdown]
# ## Part 3: Webscraping Individual Articles
# the next slide will be a snippet of code used to get the data from the article. We saved it to a dictionary, pivoted it, and then converted it to a dataframe and exported it to a csv. This was done for topics Art, Money, Politics, Sports, and Tech to get information on ["url", "title", "author", "username", "user_since", "following", "followers", "published", "claps", "text", "tags"]

# %%
#create a dictionary to fill with keys: urls, data: data from article
htmls_with_data = {}

# %%
#making for loop to scrape the data:
#starts out pinging every second then increases if 
counter, sleep_amt = 1
sleep_amt_2 = 1

for i in h:
    time.sleep(sleep_amt)
    try:
        #page request
        page_response = requests.get(i, timeout=10)

        #parsing content from page and storing it
        page_content = BeautifulSoup(page_response.content, "html.parser")

        #empty list to store user data
        data = []
    except:
        sleep_amt = sleep_amt + 1
        print("new sleep amt is " + str(sleep_amt))
        time.sleep(10)
        page_response = requests.get(i, timeout=10)
        print(page_response)

        #parsing content from page and storing it
        page_content = BeautifulSoup(page_response.content, "html.parser")

        #empty list to store user data
        data = []
    try:
        #grabs div that stores title info
        titleInfo = page_content.find_all('div',attrs={"class":"n p"})

        #finds title within titleInfo div
        href = str(titleInfo).index("<h1")
        start = str(titleInfo)[href:].index(">")+href+1
        end = str(titleInfo)[href:].index("</h1>")+href

        #appends title to data list after removing extra tags
        title = re.sub(re.compile('<.*?>'), '', str(titleInfo)[start:end])
        data.append(title)
    except:
        data.append(None)
    #try to grab author
    try:

        #<h1>Finding and Adding Author to Data</h1>

        #grabs div that stores user info
        userInfo = page_content.find_all('div',attrs={"class":"o n"})

        #finds authors name within userInfo div
        href = str(userInfo)[24:].index("<a class=")+24
        start = str(userInfo)[href:].index(">")+href+1
        end = str(userInfo)[href:].index("</a>")+href

        #appends authors name to data list
        author = str(userInfo)[start:end]
        data.append(author)
    except:
        data.append(None)
    try:
        #trying to get author page url:

        #<h1>Finding and Adding Author Page URL to Data</h1>

        #finds date within userInfo div
        href = str(userInfo)[24:].index("<a class=")
        start = str(userInfo)[href:].index("href=")+href+6
        end = str(userInfo)[start:].index("?source")+start

        #appends date to data list
        url = "medium.com" + str(userInfo)[start:end]
        data.append(url)
    except:
        data.append(None)
        
    ### PARSING THROUGH USER PAGE NOW ###
    try: #adding user data:
        #user url
        user_link = "https://" + data[2]
        #user page request
        time.sleep(sleep_amt_2)
        user_response = requests.get(user_link, timeout=5)
        #parsing content from user page to store follower count
        user_content = BeautifulSoup(user_response.content, "html.parser")
        #user tag
        user_href = re.sub("medium.com", "", data[2])
    except:
        response_code = re.findall("\d\d\d",str(user_response))[0]
        print("error getting user_data" + str(response_code))
        print(user_link)
        if response_code != "429":
            pass
        else:
            #add onto sleep
            sleep_amt_2 = sleep_amt_2 + 1
            print("new sleep amt 2 is " + str(sleep_amt_2))
            time.sleep(10)
        
            #adding user data:
            #user url
            user_link = "https://" + data[2]
            #user page request

            user_response = requests.get(user_link, timeout=5)
            #parsing content from user page to store follower count
            user_content = BeautifulSoup(user_response.content, "html.parser")
            #user tag
            user_href = re.sub("medium.com", "", data[2])

    try: #get member since
        memberInfo = user_content.find_all("span")
        year = re.findall("[0-9]{4}", str(memberInfo))[0]
        data.append(year)
    except:
        data.append(None)
    
    try: #get following:
        #returns following count and adds to data list
        followingInfo = user_content.find_all('a', attrs={"href":user_href+"/following"})
        following = re.sub("[^0-9]", "", str(followingInfo))
        data.append(following)
    except:
        data.append(None)
        
    #get follower count
    try: 
        #returns follower count and adds to data list
        followerInfo = user_content.find_all('a', attrs={"href":user_href+"/followers"})
        followers = re.sub("[^0-9]", "", str(followerInfo))
        data.append(followers)
    except:
        data.append(None)
        
    #trying to add date
    try:
        #<h1>Finding and Adding Date to Data</h1>

        #finds date within userInfo div
        href = str(userInfo)[end:].index("<a class=")+end
        start = str(userInfo)[href:].index(">")+href+1
        end = str(userInfo)[href:].index("</a>")+href

        #appends date to data list
        date = str(userInfo)[start:end]
        data.append(date)
    except:
        data.append(None)

    #tring to add clap number
    try:
        #<h1>Finding and Adding Number of Claps to Data</h1>

        #grabs all paragraphs in the article
        clapInfo = page_content.find_all('div',attrs={"class":"n o"})

        #finds claps within clapInfo div
        result = re.sub(re.compile('<.*?>'), '', str(clapInfo))
        result = re.findall("\d+", result)

        #appends claps to data list
        if len(result) == 0:
            data.append('0')

        else:
            data.append(result[0])
    except:
        data.append(None)
        
    #getting all the text data:
    try:
        
        #<h1>Adding a List of the Text Content to Data</h1>

        #grabs all paragraphs in the article
        textContent = page_content.find_all("p")
        textInfo = str(textContent)

        #RegEx that cleans paragraph data by removing html tags and extra commas
        result = re.sub(re.compile('<.*?>'), '', textInfo)
        result = re.split("\., ", result)
        result = result[:-1]
        data.append(result)
    except:
        data.append(None)
        
    #get tag info    
    try:
        tagInfo = page_content.find_all("ul")
        tags = re.sub(re.compile('<.*?>'), '', str(tagInfo))
        tags = re.sub("]", "", tags)
        tags = re.findall('[A-Z][^A-Z]*', tags)
        data.append(tags)
        #data
    except:
        data.append(None)
    
    #append html to dictionary with data
    htmls_with_data[i] = data

    
    #counter
    #print(counter)
    counter = counter + 1

# %% [markdown]
# # Looking at Word Prevalence Per Topic
# Are there any words which come up most often within various topics? Do articles tend to write about similar topics?

# %% [markdown]
# <img src = "tech2.png">

# %% [markdown]
# <img src = 'tech_med.png'>

# %% [markdown]
# <img src = 'money2.png'>

# %% [markdown]
# <img src = 'mon_med.png'>

# %% [markdown]
# <img src = 'politics2.png'>

# %% [markdown]
# <img src = "pol_med.png">

# %% [markdown]
# <img src = 'sports2.png'>

# %% [markdown]
# <img src = 'sports_med.png'>

# %% [markdown]
# There are definitely certain words which occur more often in titles for the various topics.
# The articles are from within the past few years, showcasing the most prevalent subjects being written on within the topics (assuming the title is representative of the article).
# - Technology: US, AI, and Technology are the top three. This shows the focus on AI and relative boom on articles in the subject. This may suggest that the US is leading or has a relatively large presence in the sector. (Could be due to Medium being big within the US rather than other countries as well).
# - Money: Money is first, which makes sense. There are quite a few terms about "stocks" (investment, market, stock, stocks), thus people may go to medium to see if there's a better way to invest/get insight into stock trends.
# - Politics: Trump, US, and America are the top three. It seems as though people have a lot to say about the current president. The fact that "impeachment" is present highlights current events.
# - Sports: Overall there aren't certain terms that totally dominate the title space. NBA seems to be most prevalent, possibly due to the popularity of the sport. Then nfl shows up and baseball, possibly denoting the order of popularity.

# %% [markdown]
# <h1>Data Visualization</h1>
# Harsha

# %% [markdown]
# <strong>Data Imports and Cleaning</strong>

# %%
#politics
politics = pd.read_csv("../data/Politics_data_full.csv")
politics["published"] = politics["published"].str.slice_replace(3, 6, "")
politics["title_length"] = politics['title'].str.len()

#money
money = pd.read_csv("../data/Medium_Money_Data_final.csv")
money["published"] = money["published"].str.slice_replace(3, 6, "")
money["title_length"] = money['title'].str.len()

#art
art = pd.read_csv("../data/Medium_Articles_Art_Data.csv")
art["published"] = art["published"].str.slice_replace(3, 6, "")
art["title_length"] = art['title'].str.len()

# %% [markdown]
# <h2>Month vs Claps Data</h2>

# %% [markdown]
# <strong>Politics</strong>

# %%
plt.figure(figsize=(16, 9))

pol_data1 = sns.pointplot(x="published", 
                          y="claps", 
                          data=politics, 
                          color = ".1")

pol_data1 = sns.stripplot(x="published", 
                          y="claps", 
                          data=politics, 
                          order=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

pol_data1.set_title("Politics: Month vs Claps")
pol_data1.set_ylabel("Claps")
pol_data1.set_xlabel("Month")
sns.despine()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# While most months seem to have similar clap averages, the average spikes in September likely because of election seasons, and dips after slowly because focus weens off of candidates.

# %% [markdown]
# <strong>Money</strong>

# %%
plt.figure(figsize=(16, 9))

money_data1 = sns.pointplot(x="published", 
                            y="claps", 
                            data=money, 
                            color = ".1")

money_data1 = sns.stripplot(x="published", 
                            y="claps", 
                            data=money, 
                            order=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

money_data1.set_title("Money: Month vs Claps")
money_data1.set_ylabel("Claps")
money_data1.set_xlabel("Month")
sns.despine()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once again, claps seem to have similar averages through months but the period between February and March is higher than others, potentially because this is when tax season is.

# %% [markdown]
# <strong>Art</strong>

# %%
plt.figure(figsize=(16, 9))

art_data1 = sns.pointplot(x="published", 
                          y="claps", 
                          data=art, 
                          color = ".1")
art_data1 = sns.stripplot(x="published", 
                          y="claps", 
                          data=art, 
                          order=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

art_data1.set_title("Art: Month vs Claps")
art_data1.set_ylabel("Claps")
art_data1.set_xlabel("Month")
sns.despine()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The averages through months are once again similar, with the exception of December due to an outlier data point. However, we see a rather sharp rise in average claps between the start of May through June, potentially because families could be planning a lot of visits to museums or other art galleries.

# %% [markdown]
# <h2>Title Length vs Claps Data</h2>

# %% [markdown]
# <strong>Politics</strong>

# %%
pol_data2 = sns.jointplot("title_length", 
                          "claps", 
                          data=politics, 
                          kind="kde", 
                          space=0, 
                          color="r", 
                          height=5, 
                          ratio=5, 
                          ylim=(0,270), 
                          xlim=(10,80), 
                          dropna=True)

pol_data2.set_axis_labels("Title Length",
                          "Claps")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Most politics articles find themselves with titles between 35 and 55 characters and the claps seems to average between 10 and 40.

# %% [markdown]
# <strong>Money</strong>

# %%
money_data2 = sns.jointplot("title_length", 
                            "claps", 
                            data=money, 
                            kind="kde", 
                            space=0, 
                            color="g", 
                            height=5, 
                            ratio=5, 
                            ylim=(0,460), 
                            xlim=(10,80), 
                            dropna=True)

money_data2.set_axis_labels("Title Length", 
                            "Claps")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Most money articles find themselves with titles between 35 and 45 characters and the claps seems to average between 25 and 75.

# %% [markdown]
# <strong>Art</strong>

# %%
art_data2 = sns.jointplot("title_length", 
                          "claps", 
                          data=art, 
                          kind="kde", 
                          space=0, 
                          color="b", 
                          height=5, 
                          ratio=5, 
                          ylim=(0,270), 
                          xlim=(10,80), 
                          dropna=True)

art_data2.set_axis_labels("Title Length", 
                          "Claps")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Most art articles find themselves with titles between 30 and 38 characters and the claps seems to average between 10 and 45.

# %% [markdown]
# # Visualization - Tags
# Jenna <br>
# What were the most common tags in each topic that authors chose to use for their articles?

# %% [markdown]
# ### Top 10 Tags in Technology
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Top 10 Tags in Money
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Top 10 Tags in Politics
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Top 10 Tags in Sports
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Summary of the code:
#
# - Clean tables, dropping NaN values
# - The "tags" column stores string representations of lists, so convert to lists
# - Aggregation of tags into dataframes
# - Seaborn count plots

# %% [markdown]
# ### Tag Visualization Notable Observations
#
# - Most common tag among all topics: the topic itself
# - Business and Politics notable in Technology
# - Personal and Story in Money
# - Data Science tag in Sports

# %% [markdown]
# # Modeling
# Decision Trees, KNN, Regression

# %% [markdown]
# ### GET THE TRAIN AND TEST DATA:
# Aggregate all the data, add label based on category, shuffle, and split into 20/80 splits.

# %% [markdown]
# <h1>Decision Tree Classification and Modeling</h1>
# Harsha

# %% [markdown]
# <h2>Hyperparameter Tuning</h2>

# %%
#dict to keep my results:
tuning_dict = {}
i = 0

#making vectorizer:
vector = tfidf(stop_words = "english", strip_accents = 'ascii', max_features = 100)

#a makeshift gridsearch:
for max_depth_i in range(1, 26):
    for min_samples_split_i in np.arange(.01, 0.26, .01):
        i = i + 1
        print(i)
        
        #this is how you create a basic decision tree
        dt = DecisionTreeClassifier(max_depth = max_depth_i, min_samples_split = min_samples_split_i)

# %%
        #cross validation:
        kfold = KFold(n_splits = 3)
        for train_index, test_index in kfold.split(train):
            #split into train and test:
            X_train, X_test = train["text"].iloc[train_index], train['text'].iloc[test_index]
            Y_train, Y_test = train["label"].iloc[train_index], train['label'].iloc[test_index]

            #fit vectorizer on the train data:
            X_train_trans = vector.fit_transform(X_train)

            #DO NOT refit it onto the test data!
            X_test_trans = vector.transform(X_test)

            #fit on the decision tree
            dt.fit(X_train_trans, Y_train)
            test_scores = dt.score(X_test_trans, Y_test)
            train_scores = dt.score(X_train_trans, Y_train)

            #add to the dictionary

            tuning_dict[i] = {
                "train": np.mean(train_scores), 
                "test": np.mean(test_scores), 
                "max_depth": max_depth_i, 
                "min_samples_split": min_samples_split_i
            }

# %%
tuning_dict
# Out:
# {1: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.01},
#  2: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.02},
#  3: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.03},
#  4: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.04},
#  5: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.05},
#  6: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.060000000000000005},
#  7: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.06999999999999999},
#  8: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.08},
#  9: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.09},
#  10: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.09999999999999999},
#  11: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.11},
#  12: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.12},
#  13: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.13},
#  14: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.14},
#  15: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.15000000000000002},
#  16: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.16},
#  17: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.17},
#  18: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.18000000000000002},
#  19: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.19},
#  20: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.2},
#  21: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.21000000000000002},
#  22: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.22},
#  23: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.23},
#  24: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.24000000000000002},
#  25: {'train': 0.44515832950894907,
#   'test': 0.4593850390087196,
#   'max_depth': 1,
#   'min_samples_split': 0.25},
#  26: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.01},
#  27: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.02},
#  28: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.03},
#  29: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.04},
#  30: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.05},
#  31: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.060000000000000005},
#  32: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.06999999999999999},
#  33: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.08},
#  34: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.09},
#  35: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.09999999999999999},
#  36: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.11},
#  37: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.12},
#  38: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.13},
#  39: {'train': 0.5956860945387793,
#   'test': 0.5956860945387793,
#   'max_depth': 2,
#   'min_samples_split': 0.14},
#  40: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.15000000000000002},
#  41: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.16},
#  42: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.17},
#  43: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.18000000000000002},
#  44: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.19},
#  45: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.2},
#  46: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.21000000000000002},
#  47: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.22},
#  48: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.23},
#  49: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.24000000000000002},
#  50: {'train': 0.5943093162000918,
#   'test': 0.5943093162000918,
#   'max_depth': 2,
#   'min_samples_split': 0.25},
#  51: {'train': 0.6461679669573198,
#   'test': 0.64066085360257,
#   'max_depth': 3,
#   'min_samples_split': 0.01},
#  52: {'train': 0.6461679669573198,
#   'test': 0.64066085360257,
#   'max_depth': 3,
#   'min_samples_split': 0.02},
#  53: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.03},
#  54: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.04},
#  55: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.05},
#  56: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.060000000000000005},
#  57: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.06999999999999999},
#  58: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.08},
#  59: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.09},
#  60: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.09999999999999999},
#  61: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.11},
#  62: {'train': 0.6461679669573198,
#   'test': 0.64066085360257,
#   'max_depth': 3,
#   'min_samples_split': 0.12},
#  63: {'train': 0.6461679669573198,
#   'test': 0.64066085360257,
#   'max_depth': 3,
#   'min_samples_split': 0.13},
#  64: {'train': 0.6461679669573198,
#   'test': 0.6411197797154659,
#   'max_depth': 3,
#   'min_samples_split': 0.14},
#  65: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.15000000000000002},
#  66: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.16},
#  67: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.17},
#  68: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.18000000000000002},
#  69: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.19},
#  70: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.2},
#  71: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.21000000000000002},
#  72: {'train': 0.6443322625057366,
#   'test': 0.6392840752638825,
#   'max_depth': 3,
#   'min_samples_split': 0.22},
#  73: {'train': 0.6298760899495182,
#   'test': 0.6314823313446535,
#   'max_depth': 3,
#   'min_samples_split': 0.23},
#  74: {'train': 0.6298760899495182,
#   'test': 0.6314823313446535,
#   'max_depth': 3,
#   'min_samples_split': 0.24000000000000002},
#  75: {'train': 0.6298760899495182,
#   'test': 0.6314823313446535,
#   'max_depth': 3,
#   'min_samples_split': 0.25},
#  76: {'train': 0.6961909132629647,
#   'test': 0.687471317117944,
#   'max_depth': 4,
#   'min_samples_split': 0.01},
#  77: {'train': 0.6961909132629647,
#   'test': 0.687471317117944,
#   'max_depth': 4,
#   'min_samples_split': 0.02},
#  78: {'train': 0.6961909132629647,
#   'test': 0.687471317117944,
#   'max_depth': 4,
#   'min_samples_split': 0.03},
#  79: {'train': 0.6961909132629647,
#   'test': 0.687471317117944,
#   'max_depth': 4,
#   'min_samples_split': 0.04},
#  80: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.05},
#  81: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.060000000000000005},
#  82: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.06999999999999999},
#  83: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.08},
#  84: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.09},
#  85: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.09999999999999999},
#  86: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.11},
#  87: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.12},
#  88: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.13},
#  89: {'train': 0.695273061037173,
#   'test': 0.6865534648921524,
#   'max_depth': 4,
#   'min_samples_split': 0.14},
#  90: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.15000000000000002},
#  91: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.16},
#  92: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.17},
#  93: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.18000000000000002},
#  94: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.19},
#  95: {'train': 0.6929784304726939,
#   'test': 0.6847177604405691,
#   'max_depth': 4,
#   'min_samples_split': 0.2},
#  96: {'train': 0.682193666819642,
#   'test': 0.6732446076181735,
#   'max_depth': 4,
#   'min_samples_split': 0.21000000000000002},
#  97: {'train': 0.682193666819642,
#   'test': 0.6732446076181735,
#   'max_depth': 4,
#   'min_samples_split': 0.22},
#  98: {'train': 0.6677374942634235,
#   'test': 0.6654428636989445,
#   'max_depth': 4,
#   'min_samples_split': 0.23},
#  99: {'train': 0.6677374942634235,
#   'test': 0.6654428636989445,
#   'max_depth': 4,
#   'min_samples_split': 0.24000000000000002},
#  100: {'train': 0.6677374942634235,
#   'test': 0.6654428636989445,
#   'max_depth': 4,
#   'min_samples_split': 0.25},
#  101: {'train': 0.7255621844882973,
#   'test': 0.7090408444240477,
#   'max_depth': 5,
#   'min_samples_split': 0.01},
#  102: {'train': 0.7253327214318495,
#   'test': 0.7090408444240477,
#   'max_depth': 5,
#   'min_samples_split': 0.02},
#  103: {'train': 0.7248737953189537,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.03},
#  104: {'train': 0.7248737953189537,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.04},
#  105: {'train': 0.7232675539238183,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.05},
#  106: {'train': 0.7232675539238183,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.060000000000000005},
#  107: {'train': 0.7232675539238183,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.06999999999999999},
#  108: {'train': 0.7232675539238183,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.08},
#  109: {'train': 0.7232675539238183,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.09},
#  110: {'train': 0.721202386415787,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.09999999999999999},
#  111: {'train': 0.721202386415787,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.11},
#  112: {'train': 0.721202386415787,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.12},
#  113: {'train': 0.721202386415787,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.13},
#  114: {'train': 0.721202386415787,
#   'test': 0.7085819183111519,
#   'max_depth': 5,
#   'min_samples_split': 0.14},
#  115: {'train': 0.718907755851308,
#   'test': 0.7067462138595686,
#   'max_depth': 5,
#   'min_samples_split': 0.15000000000000002},
#  116: {'train': 0.718907755851308,
#   'test': 0.7067462138595686,
#   'max_depth': 5,
#   'min_samples_split': 0.16},
#  117: {'train': 0.718907755851308,
#   'test': 0.7067462138595686,
#   'max_depth': 5,
#   'min_samples_split': 0.17},
#  118: {'train': 0.718907755851308,
#   'test': 0.7067462138595686,
#   'max_depth': 5,
#   'min_samples_split': 0.18000000000000002},
#  119: {'train': 0.718907755851308,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.19},
#  120: {'train': 0.718907755851308,
#   'test': 0.7094997705369436,
#   'max_depth': 5,
#   'min_samples_split': 0.2},
#  121: {'train': 0.708122992198256,
#   'test': 0.698026617714548,
#   'max_depth': 5,
#   'min_samples_split': 0.21000000000000002},
#  122: {'train': 0.708122992198256,
#   'test': 0.698026617714548,
#   'max_depth': 5,
#   'min_samples_split': 0.22},
#  123: {'train': 0.6936668196420376,
#   'test': 0.6902248737953189,
#   'max_depth': 5,
#   'min_samples_split': 0.23},
#  124: {'train': 0.6936668196420376,
#   'test': 0.6902248737953189,
#   'max_depth': 5,
#   'min_samples_split': 0.24000000000000002},
#  125: {'train': 0.6936668196420376,
#   'test': 0.6902248737953189,
#   'max_depth': 5,
#   'min_samples_split': 0.25},
#  126: {'train': 0.744837081229922,
#   'test': 0.7127122533272143,
#   'max_depth': 6,
#   'min_samples_split': 0.01},
#  127: {'train': 0.7416245984396512,
#   'test': 0.713630105553006,
#   'max_depth': 6,
#   'min_samples_split': 0.02},
#  128: {'train': 0.7409362092703075,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.03},
#  129: {'train': 0.7409362092703075,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.04},
#  130: {'train': 0.7386415787058284,
#   'test': 0.7150068838916934,
#   'max_depth': 6,
#   'min_samples_split': 0.05},
#  131: {'train': 0.7386415787058284,
#   'test': 0.7150068838916934,
#   'max_depth': 6,
#   'min_samples_split': 0.060000000000000005},
#  132: {'train': 0.7386415787058284,
#   'test': 0.7150068838916934,
#   'max_depth': 6,
#   'min_samples_split': 0.06999999999999999},
#  133: {'train': 0.7386415787058284,
#   'test': 0.7150068838916934,
#   'max_depth': 6,
#   'min_samples_split': 0.08},
#  134: {'train': 0.7386415787058284,
#   'test': 0.7150068838916934,
#   'max_depth': 6,
#   'min_samples_split': 0.09},
#  135: {'train': 0.7361174850849014,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.09999999999999999},
#  136: {'train': 0.7361174850849014,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.11},
#  137: {'train': 0.7361174850849014,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.12},
#  138: {'train': 0.7361174850849014,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.13},
#  139: {'train': 0.7361174850849014,
#   'test': 0.7145479577787976,
#   'max_depth': 6,
#   'min_samples_split': 0.14},
#  140: {'train': 0.7335933914639743,
#   'test': 0.7131711794401101,
#   'max_depth': 6,
#   'min_samples_split': 0.15000000000000002},
#  141: {'train': 0.7335933914639743,
#   'test': 0.7131711794401101,
#   'max_depth': 6,
#   'min_samples_split': 0.16},
#  142: {'train': 0.7335933914639743,
#   'test': 0.7131711794401101,
#   'max_depth': 6,
#   'min_samples_split': 0.17},
#  143: {'train': 0.7322166131252869,
#   'test': 0.7127122533272143,
#   'max_depth': 6,
#   'min_samples_split': 0.18000000000000002},
#  144: {'train': 0.7322166131252869,
#   'test': 0.7154658100045893,
#   'max_depth': 6,
#   'min_samples_split': 0.19},
#  145: {'train': 0.7322166131252869,
#   'test': 0.7154658100045893,
#   'max_depth': 6,
#   'min_samples_split': 0.2},
#  146: {'train': 0.7214318494722349,
#   'test': 0.7039926571821936,
#   'max_depth': 6,
#   'min_samples_split': 0.21000000000000002},
#  147: {'train': 0.7214318494722349,
#   'test': 0.7039926571821936,
#   'max_depth': 6,
#   'min_samples_split': 0.22},
#  148: {'train': 0.7069756769160165,
#   'test': 0.6961909132629647,
#   'max_depth': 6,
#   'min_samples_split': 0.23},
#  149: {'train': 0.7069756769160165,
#   'test': 0.6961909132629647,
#   'max_depth': 6,
#   'min_samples_split': 0.24000000000000002},
#  150: {'train': 0.7069756769160165,
#   'test': 0.6961909132629647,
#   'max_depth': 6,
#   'min_samples_split': 0.25},
#  151: {'train': 0.7569986232216613,
#   'test': 0.7218907755851308,
#   'max_depth': 7,
#   'min_samples_split': 0.01},
#  152: {'train': 0.7535566773749426,
#   'test': 0.7232675539238183,
#   'max_depth': 7,
#   'min_samples_split': 0.02},
#  153: {'train': 0.7514915098669114,
#   'test': 0.7237264800367141,
#   'max_depth': 7,
#   'min_samples_split': 0.03},
#  154: {'train': 0.7514915098669114,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.04},
#  155: {'train': 0.7489674162459844,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.05},
#  156: {'train': 0.7489674162459844,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.060000000000000005},
#  157: {'train': 0.7489674162459844,
#   'test': 0.7246443322625057,
#   'max_depth': 7,
#   'min_samples_split': 0.06999999999999999},
#  158: {'train': 0.7489674162459844,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.08},
#  159: {'train': 0.7489674162459844,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.09},
#  160: {'train': 0.7464433226250574,
#   'test': 0.7237264800367141,
#   'max_depth': 7,
#   'min_samples_split': 0.09999999999999999},
#  161: {'train': 0.7464433226250574,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.11},
#  162: {'train': 0.7464433226250574,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.12},
#  163: {'train': 0.7464433226250574,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.13},
#  164: {'train': 0.7464433226250574,
#   'test': 0.7241854061496099,
#   'max_depth': 7,
#   'min_samples_split': 0.14},
#  165: {'train': 0.7436897659476824,
#   'test': 0.7228086278109225,
#   'max_depth': 7,
#   'min_samples_split': 0.15000000000000002},
#  166: {'train': 0.7436897659476824,
#   'test': 0.7228086278109225,
#   'max_depth': 7,
#   'min_samples_split': 0.16},
#  167: {'train': 0.7436897659476824,
#   'test': 0.7228086278109225,
#   'max_depth': 7,
#   'min_samples_split': 0.17},
#  168: {'train': 0.7411656723267553,
#   'test': 0.7223497016980266,
#   'max_depth': 7,
#   'min_samples_split': 0.18000000000000002},
#  169: {'train': 0.7411656723267553,
#   'test': 0.7251032583754016,
#   'max_depth': 7,
#   'min_samples_split': 0.19},
#  170: {'train': 0.7411656723267553,
#   'test': 0.7251032583754016,
#   'max_depth': 7,
#   'min_samples_split': 0.2},
#  171: {'train': 0.7303809086737035,
#   'test': 0.713630105553006,
#   'max_depth': 7,
#   'min_samples_split': 0.21000000000000002},
#  172: {'train': 0.7303809086737035,
#   'test': 0.713630105553006,
#   'max_depth': 7,
#   'min_samples_split': 0.22},
#  173: {'train': 0.7159247361174851,
#   'test': 0.7058283616337769,
#   'max_depth': 7,
#   'min_samples_split': 0.23},
#  174: {'train': 0.7159247361174851,
#   'test': 0.7058283616337769,
#   'max_depth': 7,
#   'min_samples_split': 0.24000000000000002},
#  175: {'train': 0.7159247361174851,
#   'test': 0.7058283616337769,
#   'max_depth': 7,
#   'min_samples_split': 0.25},
#  176: {'train': 0.7709958696649839,
#   'test': 0.7329050022946305,
#   'max_depth': 8,
#   'min_samples_split': 0.01},
#  177: {'train': 0.7668655346489215,
#   'test': 0.7333639284075264,
#   'max_depth': 8,
#   'min_samples_split': 0.02},
#  178: {'train': 0.7636530518586507,
#   'test': 0.7338228545204222,
#   'max_depth': 8,
#   'min_samples_split': 0.03},
#  179: {'train': 0.7636530518586507,
#   'test': 0.7338228545204222,
#   'max_depth': 8,
#   'min_samples_split': 0.04},
#  180: {'train': 0.7608994951812759,
#   'test': 0.7365764111977972,
#   'max_depth': 8,
#   'min_samples_split': 0.05},
#  181: {'train': 0.7608994951812759,
#   'test': 0.7365764111977972,
#   'max_depth': 8,
#   'min_samples_split': 0.060000000000000005},
#  182: {'train': 0.7608994951812759,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.06999999999999999},
#  183: {'train': 0.7608994951812759,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.08},
#  184: {'train': 0.7608994951812759,
#   'test': 0.7365764111977972,
#   'max_depth': 8,
#   'min_samples_split': 0.09},
#  185: {'train': 0.7583754015603488,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.09999999999999999},
#  186: {'train': 0.7583754015603488,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.11},
#  187: {'train': 0.7583754015603488,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.12},
#  188: {'train': 0.7583754015603488,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.13},
#  189: {'train': 0.7583754015603488,
#   'test': 0.7361174850849014,
#   'max_depth': 8,
#   'min_samples_split': 0.14},
#  190: {'train': 0.7553923818265259,
#   'test': 0.7351996328591097,
#   'max_depth': 8,
#   'min_samples_split': 0.15000000000000002},
#  191: {'train': 0.7553923818265259,
#   'test': 0.7351996328591097,
#   'max_depth': 8,
#   'min_samples_split': 0.16},
#  192: {'train': 0.7553923818265259,
#   'test': 0.7351996328591097,
#   'max_depth': 8,
#   'min_samples_split': 0.17},
#  193: {'train': 0.7528682882055989,
#   'test': 0.7347407067462138,
#   'max_depth': 8,
#   'min_samples_split': 0.18000000000000002},
#  194: {'train': 0.7528682882055989,
#   'test': 0.7374942634235888,
#   'max_depth': 8,
#   'min_samples_split': 0.19},
#  195: {'train': 0.7528682882055989,
#   'test': 0.7374942634235888,
#   'max_depth': 8,
#   'min_samples_split': 0.2},
#  196: {'train': 0.742083524552547,
#   'test': 0.7260211106011932,
#   'max_depth': 8,
#   'min_samples_split': 0.21000000000000002},
#  197: {'train': 0.742083524552547,
#   'test': 0.7260211106011932,
#   'max_depth': 8,
#   'min_samples_split': 0.22},
#  198: {'train': 0.7276273519963286,
#   'test': 0.7182193666819642,
#   'max_depth': 8,
#   'min_samples_split': 0.23},
#  199: {'train': 0.7276273519963286,
#   'test': 0.7182193666819642,
#   'max_depth': 8,
#   'min_samples_split': 0.24000000000000002},
#  200: {'train': 0.7276273519963286,
#   'test': 0.7182193666819642,
#   'max_depth': 8,
#   'min_samples_split': 0.25},
#  201: {'train': 0.7875172097292336,
#   'test': 0.7466727856815053,
#   'max_depth': 9,
#   'min_samples_split': 0.01},
#  202: {'train': 0.7820100963744837,
#   'test': 0.7485084901330886,
#   'max_depth': 9,
#   'min_samples_split': 0.02},
#  203: {'train': 0.778797613584213,
#   'test': 0.7489674162459844,
#   'max_depth': 9,
#   'min_samples_split': 0.03},
#  204: {'train': 0.778797613584213,
#   'test': 0.7489674162459844,
#   'max_depth': 9,
#   'min_samples_split': 0.04},
#  205: {'train': 0.7758145938503901,
#   'test': 0.7498852684717761,
#   'max_depth': 9,
#   'min_samples_split': 0.05},
#  206: {'train': 0.7758145938503901,
#   'test': 0.7498852684717761,
#   'max_depth': 9,
#   'min_samples_split': 0.060000000000000005},
#  207: {'train': 0.7748967416245984,
#   'test': 0.7480495640201927,
#   'max_depth': 9,
#   'min_samples_split': 0.06999999999999999},
#  208: {'train': 0.7748967416245984,
#   'test': 0.7480495640201927,
#   'max_depth': 9,
#   'min_samples_split': 0.08},
#  209: {'train': 0.7746672785681505,
#   'test': 0.7489674162459844,
#   'max_depth': 9,
#   'min_samples_split': 0.09},
#  210: {'train': 0.7721431849472234,
#   'test': 0.7489674162459844,
#   'max_depth': 9,
#   'min_samples_split': 0.09999999999999999},
#  211: {'train': 0.7721431849472234,
#   'test': 0.7489674162459844,
#   'max_depth': 9,
#   'min_samples_split': 0.11},
#  212: {'train': 0.7716842588343277,
#   'test': 0.7485084901330886,
#   'max_depth': 9,
#   'min_samples_split': 0.12},
#  213: {'train': 0.7716842588343277,
#   'test': 0.7485084901330886,
#   'max_depth': 9,
#   'min_samples_split': 0.13},
#  214: {'train': 0.7716842588343277,
#   'test': 0.7485084901330886,
#   'max_depth': 9,
#   'min_samples_split': 0.14},
#  215: {'train': 0.7684717760440569,
#   'test': 0.747590637907297,
#   'max_depth': 9,
#   'min_samples_split': 0.15000000000000002},
#  216: {'train': 0.7684717760440569,
#   'test': 0.747590637907297,
#   'max_depth': 9,
#   'min_samples_split': 0.16},
#  217: {'train': 0.7684717760440569,
#   'test': 0.747590637907297,
#   'max_depth': 9,
#   'min_samples_split': 0.17},
#  218: {'train': 0.7659476824231298,
#   'test': 0.7471317117944011,
#   'max_depth': 9,
#   'min_samples_split': 0.18000000000000002},
#  219: {'train': 0.7659476824231298,
#   'test': 0.7498852684717761,
#   'max_depth': 9,
#   'min_samples_split': 0.19},
#  220: {'train': 0.7659476824231298,
#   'test': 0.7498852684717761,
#   'max_depth': 9,
#   'min_samples_split': 0.2},
#  221: {'train': 0.755162918770078,
#   'test': 0.7384121156493805,
#   'max_depth': 9,
#   'min_samples_split': 0.21000000000000002},
#  222: {'train': 0.755162918770078,
#   'test': 0.7384121156493805,
#   'max_depth': 9,
#   'min_samples_split': 0.22},
#  223: {'train': 0.7407067462138596,
#   'test': 0.7306103717301514,
#   'max_depth': 9,
#   'min_samples_split': 0.23},
#  224: {'train': 0.7407067462138596,
#   'test': 0.7306103717301514,
#   'max_depth': 9,
#   'min_samples_split': 0.24000000000000002},
#  225: {'train': 0.7407067462138596,
#   'test': 0.7306103717301514,
#   'max_depth': 9,
#   'min_samples_split': 0.25},
#  226: {'train': 0.7989903625516291,
#   'test': 0.7521798990362552,
#   'max_depth': 10,
#   'min_samples_split': 0.01},
#  227: {'train': 0.7927948600275355,
#   'test': 0.7530977512620468,
#   'max_depth': 10,
#   'min_samples_split': 0.02},
#  228: {'train': 0.7886645250114731,
#   'test': 0.752638825149151,
#   'max_depth': 10,
#   'min_samples_split': 0.03},
#  229: {'train': 0.7884350619550252,
#   'test': 0.7535566773749426,
#   'max_depth': 10,
#   'min_samples_split': 0.04},
#  230: {'train': 0.7854520422212024,
#   'test': 0.7544745296007342,
#   'max_depth': 10,
#   'min_samples_split': 0.05},
#  231: {'train': 0.7854520422212024,
#   'test': 0.7535566773749426,
#   'max_depth': 10,
#   'min_samples_split': 0.060000000000000005},
#  232: {'train': 0.7843047269389628,
#   'test': 0.7530977512620468,
#   'max_depth': 10,
#   'min_samples_split': 0.06999999999999999},
#  233: {'train': 0.7843047269389628,
#   'test': 0.7540156034878385,
#   'max_depth': 10,
#   'min_samples_split': 0.08},
#  234: {'train': 0.7840752638825149,
#   'test': 0.7549334557136301,
#   'max_depth': 10,
#   'min_samples_split': 0.09},
#  235: {'train': 0.7815511702615879,
#   'test': 0.7540156034878385,
#   'max_depth': 10,
#   'min_samples_split': 0.09999999999999999},
#  236: {'train': 0.7813217072051399,
#   'test': 0.7553923818265259,
#   'max_depth': 10,
#   'min_samples_split': 0.11},
#  237: {'train': 0.7808627810922442,
#   'test': 0.7549334557136301,
#   'max_depth': 10,
#   'min_samples_split': 0.12},
#  238: {'train': 0.7808627810922442,
#   'test': 0.7549334557136301,
#   'max_depth': 10,
#   'min_samples_split': 0.13},
#  239: {'train': 0.7808627810922442,
#   'test': 0.7549334557136301,
#   'max_depth': 10,
#   'min_samples_split': 0.14},
#  240: {'train': 0.7774208352455255,
#   'test': 0.7535566773749426,
#   'max_depth': 10,
#   'min_samples_split': 0.15000000000000002},
#  241: {'train': 0.7774208352455255,
#   'test': 0.7535566773749426,
#   'max_depth': 10,
#   'min_samples_split': 0.16},
#  242: {'train': 0.7774208352455255,
#   'test': 0.7535566773749426,
#   'max_depth': 10,
#   'min_samples_split': 0.17},
#  243: {'train': 0.7748967416245984,
#   'test': 0.7530977512620468,
#   'max_depth': 10,
#   'min_samples_split': 0.18000000000000002},
#  244: {'train': 0.7748967416245984,
#   'test': 0.7558513079394218,
#   'max_depth': 10,
#   'min_samples_split': 0.19},
#  245: {'train': 0.7748967416245984,
#   'test': 0.7558513079394218,
#   'max_depth': 10,
#   'min_samples_split': 0.2},
#  246: {'train': 0.7641119779715466,
#   'test': 0.7443781551170262,
#   'max_depth': 10,
#   'min_samples_split': 0.21000000000000002},
#  247: {'train': 0.7641119779715466,
#   'test': 0.7443781551170262,
#   'max_depth': 10,
#   'min_samples_split': 0.22},
#  248: {'train': 0.7496558054153282,
#   'test': 0.7365764111977972,
#   'max_depth': 10,
#   'min_samples_split': 0.23},
#  249: {'train': 0.7496558054153282,
#   'test': 0.7365764111977972,
#   'max_depth': 10,
#   'min_samples_split': 0.24000000000000002},
#  250: {'train': 0.7496558054153282,
#   'test': 0.7365764111977972,
#   'max_depth': 10,
#   'min_samples_split': 0.25},
#  251: {'train': 0.8015144561725562,
#   'test': 0.744837081229922,
#   'max_depth': 11,
#   'min_samples_split': 0.01},
#  252: {'train': 0.7946305644791188,
#   'test': 0.747590637907297,
#   'max_depth': 11,
#   'min_samples_split': 0.02},
#  253: {'train': 0.7905002294630564,
#   'test': 0.7466727856815053,
#   'max_depth': 11,
#   'min_samples_split': 0.03},
#  254: {'train': 0.7900413033501607,
#   'test': 0.7471317117944011,
#   'max_depth': 11,
#   'min_samples_split': 0.04},
#  255: {'train': 0.7870582836163378,
#   'test': 0.7480495640201927,
#   'max_depth': 11,
#   'min_samples_split': 0.05},
#  256: {'train': 0.7870582836163378,
#   'test': 0.7480495640201927,
#   'max_depth': 11,
#   'min_samples_split': 0.060000000000000005},
#  257: {'train': 0.7859109683340982,
#   'test': 0.747590637907297,
#   'max_depth': 11,
#   'min_samples_split': 0.06999999999999999},
#  258: {'train': 0.7859109683340982,
#   'test': 0.747590637907297,
#   'max_depth': 11,
#   'min_samples_split': 0.08},
#  259: {'train': 0.7854520422212024,
#   'test': 0.7485084901330886,
#   'max_depth': 11,
#   'min_samples_split': 0.09},
#  260: {'train': 0.7829279486002754,
#   'test': 0.7485084901330886,
#   'max_depth': 11,
#   'min_samples_split': 0.09999999999999999},
#  261: {'train': 0.7824690224873795,
#   'test': 0.7485084901330886,
#   'max_depth': 11,
#   'min_samples_split': 0.11},
#  262: {'train': 0.7820100963744837,
#   'test': 0.7480495640201927,
#   'max_depth': 11,
#   'min_samples_split': 0.12},
#  263: {'train': 0.7820100963744837,
#   'test': 0.7480495640201927,
#   'max_depth': 11,
#   'min_samples_split': 0.13},
#  264: {'train': 0.7820100963744837,
#   'test': 0.7480495640201927,
#   'max_depth': 11,
#   'min_samples_split': 0.14},
#  265: {'train': 0.7783386874713171,
#   'test': 0.7471317117944011,
#   'max_depth': 11,
#   'min_samples_split': 0.15000000000000002},
#  266: {'train': 0.7783386874713171,
#   'test': 0.7471317117944011,
#   'max_depth': 11,
#   'min_samples_split': 0.16},
#  267: {'train': 0.7783386874713171,
#   'test': 0.7471317117944011,
#   'max_depth': 11,
#   'min_samples_split': 0.17},
#  268: {'train': 0.7758145938503901,
#   'test': 0.7466727856815053,
#   'max_depth': 11,
#   'min_samples_split': 0.18000000000000002},
#  269: {'train': 0.7758145938503901,
#   'test': 0.7494263423588802,
#   'max_depth': 11,
#   'min_samples_split': 0.19},
#  270: {'train': 0.7758145938503901,
#   'test': 0.7494263423588802,
#   'max_depth': 11,
#   'min_samples_split': 0.2},
#  271: {'train': 0.7650298301973383,
#   'test': 0.7379531895364846,
#   'max_depth': 11,
#   'min_samples_split': 0.21000000000000002},
#  272: {'train': 0.7650298301973383,
#   'test': 0.7379531895364846,
#   'max_depth': 11,
#   'min_samples_split': 0.22},
#  273: {'train': 0.7505736576411198,
#   'test': 0.7301514456172556,
#   'max_depth': 11,
#   'min_samples_split': 0.23},
#  274: {'train': 0.7505736576411198,
#   'test': 0.7301514456172556,
#   'max_depth': 11,
#   'min_samples_split': 0.24000000000000002},
#  275: {'train': 0.7505736576411198,
#   'test': 0.7301514456172556,
#   'max_depth': 11,
#   'min_samples_split': 0.25},
#  276: {'train': 0.807251032583754,
#   'test': 0.7494263423588802,
#   'max_depth': 12,
#   'min_samples_split': 0.01},
#  277: {'train': 0.799449288664525,
#   'test': 0.7549334557136301,
#   'max_depth': 12,
#   'min_samples_split': 0.02},
#  278: {'train': 0.7927948600275355,
#   'test': 0.7471317117944011,
#   'max_depth': 12,
#   'min_samples_split': 0.03},
#  279: {'train': 0.7921064708581919,
#   'test': 0.7471317117944011,
#   'max_depth': 12,
#   'min_samples_split': 0.04},
#  280: {'train': 0.789123451124369,
#   'test': 0.7480495640201927,
#   'max_depth': 12,
#   'min_samples_split': 0.05},
#  281: {'train': 0.789123451124369,
#   'test': 0.7485084901330886,
#   'max_depth': 12,
#   'min_samples_split': 0.060000000000000005},
#  282: {'train': 0.7879761358421294,
#   'test': 0.747590637907297,
#   'max_depth': 12,
#   'min_samples_split': 0.06999999999999999},
#  283: {'train': 0.7879761358421294,
#   'test': 0.7480495640201927,
#   'max_depth': 12,
#   'min_samples_split': 0.08},
#  284: {'train': 0.7872877466727857,
#   'test': 0.7489674162459844,
#   'max_depth': 12,
#   'min_samples_split': 0.09},
#  285: {'train': 0.7847636530518587,
#   'test': 0.7485084901330886,
#   'max_depth': 12,
#   'min_samples_split': 0.09999999999999999},
#  286: {'train': 0.7840752638825149,
#   'test': 0.7489674162459844,
#   'max_depth': 12,
#   'min_samples_split': 0.11},
#  287: {'train': 0.7836163377696191,
#   'test': 0.7485084901330886,
#   'max_depth': 12,
#   'min_samples_split': 0.12},
#  288: {'train': 0.7836163377696191,
#   'test': 0.7485084901330886,
#   'max_depth': 12,
#   'min_samples_split': 0.13},
#  289: {'train': 0.7836163377696191,
#   'test': 0.7485084901330886,
#   'max_depth': 12,
#   'min_samples_split': 0.14},
#  290: {'train': 0.7799449288664525,
#   'test': 0.747590637907297,
#   'max_depth': 12,
#   'min_samples_split': 0.15000000000000002},
#  291: {'train': 0.7799449288664525,
#   'test': 0.747590637907297,
#   'max_depth': 12,
#   'min_samples_split': 0.16},
#  292: {'train': 0.7799449288664525,
#   'test': 0.747590637907297,
#   'max_depth': 12,
#   'min_samples_split': 0.17},
#  293: {'train': 0.7774208352455255,
#   'test': 0.7471317117944011,
#   'max_depth': 12,
#   'min_samples_split': 0.18000000000000002},
#  294: {'train': 0.7774208352455255,
#   'test': 0.7498852684717761,
#   'max_depth': 12,
#   'min_samples_split': 0.19},
#  295: {'train': 0.7774208352455255,
#   'test': 0.7498852684717761,
#   'max_depth': 12,
#   'min_samples_split': 0.2},
#  296: {'train': 0.7666360715924736,
#   'test': 0.7384121156493805,
#   'max_depth': 12,
#   'min_samples_split': 0.21000000000000002},
#  297: {'train': 0.7666360715924736,
#   'test': 0.7384121156493805,
#   'max_depth': 12,
#   'min_samples_split': 0.22},
#  298: {'train': 0.7521798990362552,
#   'test': 0.7306103717301514,
#   'max_depth': 12,
#   'min_samples_split': 0.23},
#  299: {'train': 0.7521798990362552,
#   'test': 0.7306103717301514,
#   'max_depth': 12,
#   'min_samples_split': 0.24000000000000002},
#  300: {'train': 0.7521798990362552,
#   'test': 0.7306103717301514,
#   'max_depth': 12,
#   'min_samples_split': 0.25},
#  301: {'train': 0.8136759981642956,
#   'test': 0.7503441945846718,
#   'max_depth': 13,
#   'min_samples_split': 0.01},
#  302: {'train': 0.8031206975676916,
#   'test': 0.7535566773749426,
#   'max_depth': 13,
#   'min_samples_split': 0.02},
#  303: {'train': 0.7964662689307022,
#   'test': 0.7457549334557136,
#   'max_depth': 13,
#   'min_samples_split': 0.03},
#  304: {'train': 0.7955484167049105,
#   'test': 0.7462138595686094,
#   'max_depth': 13,
#   'min_samples_split': 0.04},
#  305: {'train': 0.7923359339146397,
#   'test': 0.7471317117944011,
#   'max_depth': 13,
#   'min_samples_split': 0.05},
#  306: {'train': 0.7923359339146397,
#   'test': 0.7471317117944011,
#   'max_depth': 13,
#   'min_samples_split': 0.060000000000000005},
#  307: {'train': 0.7911886186324002,
#   'test': 0.7466727856815053,
#   'max_depth': 13,
#   'min_samples_split': 0.06999999999999999},
#  308: {'train': 0.7911886186324002,
#   'test': 0.7466727856815053,
#   'max_depth': 13,
#   'min_samples_split': 0.08},
#  309: {'train': 0.7902707664066085,
#   'test': 0.747590637907297,
#   'max_depth': 13,
#   'min_samples_split': 0.09},
#  310: {'train': 0.7877466727856816,
#   'test': 0.747590637907297,
#   'max_depth': 13,
#   'min_samples_split': 0.09999999999999999},
#  311: {'train': 0.7868288205598899,
#   'test': 0.7480495640201927,
#   'max_depth': 13,
#   'min_samples_split': 0.11},
#  312: {'train': 0.786369894446994,
#   'test': 0.747590637907297,
#   'max_depth': 13,
#   'min_samples_split': 0.12},
#  313: {'train': 0.786369894446994,
#   'test': 0.747590637907297,
#   'max_depth': 13,
#   'min_samples_split': 0.13},
#  314: {'train': 0.786369894446994,
#   'test': 0.747590637907297,
#   'max_depth': 13,
#   'min_samples_split': 0.14},
#  315: {'train': 0.7826984855438275,
#   'test': 0.7466727856815053,
#   'max_depth': 13,
#   'min_samples_split': 0.15000000000000002},
#  316: {'train': 0.7826984855438275,
#   'test': 0.7466727856815053,
#   'max_depth': 13,
#   'min_samples_split': 0.16},
#  317: {'train': 0.7826984855438275,
#   'test': 0.7466727856815053,
#   'max_depth': 13,
#   'min_samples_split': 0.17},
#  318: {'train': 0.7801743919229004,
#   'test': 0.7462138595686094,
#   'max_depth': 13,
#   'min_samples_split': 0.18000000000000002},
#  319: {'train': 0.7801743919229004,
#   'test': 0.7489674162459844,
#   'max_depth': 13,
#   'min_samples_split': 0.19},
#  320: {'train': 0.7801743919229004,
#   'test': 0.7489674162459844,
#   'max_depth': 13,
#   'min_samples_split': 0.2},
#  321: {'train': 0.7693896282698486,
#   'test': 0.7374942634235888,
#   'max_depth': 13,
#   'min_samples_split': 0.21000000000000002},
#  322: {'train': 0.7693896282698486,
#   'test': 0.7374942634235888,
#   'max_depth': 13,
#   'min_samples_split': 0.22},
#  323: {'train': 0.7549334557136301,
#   'test': 0.7296925195043598,
#   'max_depth': 13,
#   'min_samples_split': 0.23},
#  324: {'train': 0.7549334557136301,
#   'test': 0.7296925195043598,
#   'max_depth': 13,
#   'min_samples_split': 0.24000000000000002},
#  325: {'train': 0.7549334557136301,
#   'test': 0.7296925195043598,
#   'max_depth': 13,
#   'min_samples_split': 0.25},
#  326: {'train': 0.8187241854061497,
#   'test': 0.7503441945846718,
#   'max_depth': 14,
#   'min_samples_split': 0.01},
#  327: {'train': 0.8058742542450665,
#   'test': 0.7535566773749426,
#   'max_depth': 14,
#   'min_samples_split': 0.02},
#  328: {'train': 0.7992198256080771,
#   'test': 0.7452960073428178,
#   'max_depth': 14,
#   'min_samples_split': 0.03},
#  329: {'train': 0.7978430472693896,
#   'test': 0.7466727856815053,
#   'max_depth': 14,
#   'min_samples_split': 0.04},
#  330: {'train': 0.7946305644791188,
#   'test': 0.747590637907297,
#   'max_depth': 14,
#   'min_samples_split': 0.05},
#  331: {'train': 0.7946305644791188,
#   'test': 0.747590637907297,
#   'max_depth': 14,
#   'min_samples_split': 0.060000000000000005},
#  332: {'train': 0.7934832491968793,
#   'test': 0.7471317117944011,
#   'max_depth': 14,
#   'min_samples_split': 0.06999999999999999},
#  333: {'train': 0.7934832491968793,
#   'test': 0.7471317117944011,
#   'max_depth': 14,
#   'min_samples_split': 0.08},
#  334: {'train': 0.7923359339146397,
#   'test': 0.7480495640201927,
#   'max_depth': 14,
#   'min_samples_split': 0.09},
#  335: {'train': 0.7898118402937128,
#   'test': 0.7480495640201927,
#   'max_depth': 14,
#   'min_samples_split': 0.09999999999999999},
#  336: {'train': 0.7888939880679211,
#   'test': 0.7485084901330886,
#   'max_depth': 14,
#   'min_samples_split': 0.11},
#  337: {'train': 0.7884350619550252,
#   'test': 0.7480495640201927,
#   'max_depth': 14,
#   'min_samples_split': 0.12},
#  338: {'train': 0.7884350619550252,
#   'test': 0.7480495640201927,
#   'max_depth': 14,
#   'min_samples_split': 0.13},
#  339: {'train': 0.7884350619550252,
#   'test': 0.7480495640201927,
#   'max_depth': 14,
#   'min_samples_split': 0.14},
#  340: {'train': 0.7847636530518587,
#   'test': 0.7471317117944011,
#   'max_depth': 14,
#   'min_samples_split': 0.15000000000000002},
#  341: {'train': 0.7847636530518587,
#   'test': 0.7471317117944011,
#   'max_depth': 14,
#   'min_samples_split': 0.16},
#  342: {'train': 0.7847636530518587,
#   'test': 0.7471317117944011,
#   'max_depth': 14,
#   'min_samples_split': 0.17},
#  343: {'train': 0.7822395594309316,
#   'test': 0.7466727856815053,
#   'max_depth': 14,
#   'min_samples_split': 0.18000000000000002},
#  344: {'train': 0.7822395594309316,
#   'test': 0.7494263423588802,
#   'max_depth': 14,
#   'min_samples_split': 0.19},
#  345: {'train': 0.7822395594309316,
#   'test': 0.7494263423588802,
#   'max_depth': 14,
#   'min_samples_split': 0.2},
#  346: {'train': 0.7714547957778798,
#   'test': 0.7379531895364846,
#   'max_depth': 14,
#   'min_samples_split': 0.21000000000000002},
#  347: {'train': 0.7714547957778798,
#   'test': 0.7379531895364846,
#   'max_depth': 14,
#   'min_samples_split': 0.22},
#  348: {'train': 0.7569986232216613,
#   'test': 0.7301514456172556,
#   'max_depth': 14,
#   'min_samples_split': 0.23},
#  349: {'train': 0.7569986232216613,
#   'test': 0.7301514456172556,
#   'max_depth': 14,
#   'min_samples_split': 0.24000000000000002},
#  350: {'train': 0.7569986232216613,
#   'test': 0.7301514456172556,
#   'max_depth': 14,
#   'min_samples_split': 0.25},
#  351: {'train': 0.8214777420835245,
#   'test': 0.7457549334557136,
#   'max_depth': 15,
#   'min_samples_split': 0.01},
#  352: {'train': 0.8067921064708582,
#   'test': 0.7498852684717761,
#   'max_depth': 15,
#   'min_samples_split': 0.02},
#  353: {'train': 0.8001376778338688,
#   'test': 0.742083524552547,
#   'max_depth': 15,
#   'min_samples_split': 0.03},
#  354: {'train': 0.7983019733822855,
#   'test': 0.7430013767783387,
#   'max_depth': 15,
#   'min_samples_split': 0.04},
#  355: {'train': 0.7950894905920147,
#   'test': 0.7439192290041303,
#   'max_depth': 15,
#   'min_samples_split': 0.05},
#  356: {'train': 0.7950894905920147,
#   'test': 0.7439192290041303,
#   'max_depth': 15,
#   'min_samples_split': 0.060000000000000005},
#  357: {'train': 0.7939421753097752,
#   'test': 0.7434603028912345,
#   'max_depth': 15,
#   'min_samples_split': 0.06999999999999999},
#  358: {'train': 0.7939421753097752,
#   'test': 0.7434603028912345,
#   'max_depth': 15,
#   'min_samples_split': 0.08},
#  359: {'train': 0.7925653969710876,
#   'test': 0.7443781551170262,
#   'max_depth': 15,
#   'min_samples_split': 0.09},
#  360: {'train': 0.7900413033501607,
#   'test': 0.7443781551170262,
#   'max_depth': 15,
#   'min_samples_split': 0.09999999999999999},
#  361: {'train': 0.789123451124369,
#   'test': 0.744837081229922,
#   'max_depth': 15,
#   'min_samples_split': 0.11},
#  362: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 15,
#   'min_samples_split': 0.12},
#  363: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 15,
#   'min_samples_split': 0.13},
#  364: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 15,
#   'min_samples_split': 0.14},
#  365: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 15,
#   'min_samples_split': 0.15000000000000002},
#  366: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 15,
#   'min_samples_split': 0.16},
#  367: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 15,
#   'min_samples_split': 0.17},
#  368: {'train': 0.7824690224873795,
#   'test': 0.7430013767783387,
#   'max_depth': 15,
#   'min_samples_split': 0.18000000000000002},
#  369: {'train': 0.7824690224873795,
#   'test': 0.7457549334557136,
#   'max_depth': 15,
#   'min_samples_split': 0.19},
#  370: {'train': 0.7824690224873795,
#   'test': 0.7457549334557136,
#   'max_depth': 15,
#   'min_samples_split': 0.2},
#  371: {'train': 0.7716842588343277,
#   'test': 0.7342817806333181,
#   'max_depth': 15,
#   'min_samples_split': 0.21000000000000002},
#  372: {'train': 0.7716842588343277,
#   'test': 0.7342817806333181,
#   'max_depth': 15,
#   'min_samples_split': 0.22},
#  373: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 15,
#   'min_samples_split': 0.23},
#  374: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 15,
#   'min_samples_split': 0.24000000000000002},
#  375: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 15,
#   'min_samples_split': 0.25},
#  376: {'train': 0.82308398347866,
#   'test': 0.7471317117944011,
#   'max_depth': 16,
#   'min_samples_split': 0.01},
#  377: {'train': 0.8081688848095456,
#   'test': 0.7508031206975677,
#   'max_depth': 16,
#   'min_samples_split': 0.02},
#  378: {'train': 0.8003671408903167,
#   'test': 0.7411656723267553,
#   'max_depth': 16,
#   'min_samples_split': 0.03},
#  379: {'train': 0.7983019733822855,
#   'test': 0.7430013767783387,
#   'max_depth': 16,
#   'min_samples_split': 0.04},
#  380: {'train': 0.7950894905920147,
#   'test': 0.7439192290041303,
#   'max_depth': 16,
#   'min_samples_split': 0.05},
#  381: {'train': 0.7950894905920147,
#   'test': 0.7439192290041303,
#   'max_depth': 16,
#   'min_samples_split': 0.060000000000000005},
#  382: {'train': 0.7939421753097752,
#   'test': 0.7434603028912345,
#   'max_depth': 16,
#   'min_samples_split': 0.06999999999999999},
#  383: {'train': 0.7939421753097752,
#   'test': 0.7434603028912345,
#   'max_depth': 16,
#   'min_samples_split': 0.08},
#  384: {'train': 0.7925653969710876,
#   'test': 0.7443781551170262,
#   'max_depth': 16,
#   'min_samples_split': 0.09},
#  385: {'train': 0.7900413033501607,
#   'test': 0.7443781551170262,
#   'max_depth': 16,
#   'min_samples_split': 0.09999999999999999},
#  386: {'train': 0.789123451124369,
#   'test': 0.744837081229922,
#   'max_depth': 16,
#   'min_samples_split': 0.11},
#  387: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 16,
#   'min_samples_split': 0.12},
#  388: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 16,
#   'min_samples_split': 0.13},
#  389: {'train': 0.7886645250114731,
#   'test': 0.7443781551170262,
#   'max_depth': 16,
#   'min_samples_split': 0.14},
#  390: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 16,
#   'min_samples_split': 0.15000000000000002},
#  391: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 16,
#   'min_samples_split': 0.16},
#  392: {'train': 0.7849931161083066,
#   'test': 0.7434603028912345,
#   'max_depth': 16,
#   'min_samples_split': 0.17},
#  393: {'train': 0.7824690224873795,
#   'test': 0.7430013767783387,
#   'max_depth': 16,
#   'min_samples_split': 0.18000000000000002},
#  394: {'train': 0.7824690224873795,
#   'test': 0.7457549334557136,
#   'max_depth': 16,
#   'min_samples_split': 0.19},
#  395: {'train': 0.7824690224873795,
#   'test': 0.7457549334557136,
#   'max_depth': 16,
#   'min_samples_split': 0.2},
#  396: {'train': 0.7716842588343277,
#   'test': 0.7342817806333181,
#   'max_depth': 16,
#   'min_samples_split': 0.21000000000000002},
#  397: {'train': 0.7716842588343277,
#   'test': 0.7342817806333181,
#   'max_depth': 16,
#   'min_samples_split': 0.22},
#  398: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 16,
#   'min_samples_split': 0.23},
#  399: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 16,
#   'min_samples_split': 0.24000000000000002},
#  400: {'train': 0.7572280862781092,
#   'test': 0.726480036714089,
#   'max_depth': 16,
#   'min_samples_split': 0.25},
#  401: {'train': 0.8276732446076182,
#   'test': 0.7489674162459844,
#   'max_depth': 17,
#   'min_samples_split': 0.01},
#  402: {'train': 0.8127581459385039,
#   'test': 0.7521798990362552,
#   'max_depth': 17,
#   'min_samples_split': 0.02},
#  403: {'train': 0.8026617714547958,
#   'test': 0.7425424506654429,
#   'max_depth': 17,
#   'min_samples_split': 0.03},
#  404: {'train': 0.8003671408903167,
#   'test': 0.7439192290041303,
#   'max_depth': 17,
#   'min_samples_split': 0.04},
#  405: {'train': 0.7971546581000459,
#   'test': 0.744837081229922,
#   'max_depth': 17,
#   'min_samples_split': 0.05},
#  406: {'train': 0.7971546581000459,
#   'test': 0.744837081229922,
#   'max_depth': 17,
#   'min_samples_split': 0.060000000000000005},
# ...
#   'max_depth': 20,
#   'min_samples_split': 0.16},
#  492: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 20,
#   'min_samples_split': 0.17},
#  493: {'train': 0.7845341899954107,
#   'test': 0.742083524552547,
#   'max_depth': 20,
#   'min_samples_split': 0.18000000000000002},
#  494: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 20,
#   'min_samples_split': 0.19},
#  495: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 20,
#   'min_samples_split': 0.2},
#  496: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 20,
#   'min_samples_split': 0.21000000000000002},
#  497: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 20,
#   'min_samples_split': 0.22},
#  498: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 20,
#   'min_samples_split': 0.23},
#  499: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 20,
#   'min_samples_split': 0.24000000000000002},
#  500: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 20,
#   'min_samples_split': 0.25},
#  501: {'train': 0.830656264341441,
#   'test': 0.7443781551170262,
#   'max_depth': 21,
#   'min_samples_split': 0.01},
#  502: {'train': 0.8134465351078476,
#   'test': 0.7503441945846718,
#   'max_depth': 21,
#   'min_samples_split': 0.02},
#  503: {'train': 0.8031206975676916,
#   'test': 0.7407067462138596,
#   'max_depth': 21,
#   'min_samples_split': 0.03},
#  504: {'train': 0.8003671408903167,
#   'test': 0.742083524552547,
#   'max_depth': 21,
#   'min_samples_split': 0.04},
#  505: {'train': 0.7971546581000459,
#   'test': 0.7430013767783387,
#   'max_depth': 21,
#   'min_samples_split': 0.05},
#  506: {'train': 0.7971546581000459,
#   'test': 0.7430013767783387,
#   'max_depth': 21,
#   'min_samples_split': 0.060000000000000005},
#  507: {'train': 0.7960073428178064,
#   'test': 0.7425424506654429,
#   'max_depth': 21,
#   'min_samples_split': 0.06999999999999999},
#  508: {'train': 0.7960073428178064,
#   'test': 0.7425424506654429,
#   'max_depth': 21,
#   'min_samples_split': 0.08},
#  509: {'train': 0.7946305644791188,
#   'test': 0.7434603028912345,
#   'max_depth': 21,
#   'min_samples_split': 0.09},
#  510: {'train': 0.7921064708581919,
#   'test': 0.7434603028912345,
#   'max_depth': 21,
#   'min_samples_split': 0.09999999999999999},
#  511: {'train': 0.7911886186324002,
#   'test': 0.7439192290041303,
#   'max_depth': 21,
#   'min_samples_split': 0.11},
#  512: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 21,
#   'min_samples_split': 0.12},
#  513: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 21,
#   'min_samples_split': 0.13},
#  514: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 21,
#   'min_samples_split': 0.14},
#  515: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 21,
#   'min_samples_split': 0.15000000000000002},
#  516: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 21,
#   'min_samples_split': 0.16},
#  517: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 21,
#   'min_samples_split': 0.17},
#  518: {'train': 0.7845341899954107,
#   'test': 0.742083524552547,
#   'max_depth': 21,
#   'min_samples_split': 0.18000000000000002},
#  519: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 21,
#   'min_samples_split': 0.19},
#  520: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 21,
#   'min_samples_split': 0.2},
#  521: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 21,
#   'min_samples_split': 0.21000000000000002},
#  522: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 21,
#   'min_samples_split': 0.22},
#  523: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 21,
#   'min_samples_split': 0.23},
#  524: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 21,
#   'min_samples_split': 0.24000000000000002},
#  525: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 21,
#   'min_samples_split': 0.25},
#  526: {'train': 0.8313446535107848,
#   'test': 0.7466727856815053,
#   'max_depth': 22,
#   'min_samples_split': 0.01},
#  527: {'train': 0.8134465351078476,
#   'test': 0.7503441945846718,
#   'max_depth': 22,
#   'min_samples_split': 0.02},
#  528: {'train': 0.8031206975676916,
#   'test': 0.7402478201009638,
#   'max_depth': 22,
#   'min_samples_split': 0.03},
#  529: {'train': 0.8003671408903167,
#   'test': 0.742083524552547,
#   'max_depth': 22,
#   'min_samples_split': 0.04},
#  530: {'train': 0.7971546581000459,
#   'test': 0.7430013767783387,
#   'max_depth': 22,
#   'min_samples_split': 0.05},
#  531: {'train': 0.7971546581000459,
#   'test': 0.7430013767783387,
#   'max_depth': 22,
#   'min_samples_split': 0.060000000000000005},
#  532: {'train': 0.7960073428178064,
#   'test': 0.7425424506654429,
#   'max_depth': 22,
#   'min_samples_split': 0.06999999999999999},
#  533: {'train': 0.7960073428178064,
#   'test': 0.7425424506654429,
#   'max_depth': 22,
#   'min_samples_split': 0.08},
#  534: {'train': 0.7946305644791188,
#   'test': 0.7434603028912345,
#   'max_depth': 22,
#   'min_samples_split': 0.09},
#  535: {'train': 0.7921064708581919,
#   'test': 0.7434603028912345,
#   'max_depth': 22,
#   'min_samples_split': 0.09999999999999999},
#  536: {'train': 0.7911886186324002,
#   'test': 0.7439192290041303,
#   'max_depth': 22,
#   'min_samples_split': 0.11},
#  537: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 22,
#   'min_samples_split': 0.12},
#  538: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 22,
#   'min_samples_split': 0.13},
#  539: {'train': 0.7907296925195043,
#   'test': 0.7434603028912345,
#   'max_depth': 22,
#   'min_samples_split': 0.14},
#  540: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 22,
#   'min_samples_split': 0.15000000000000002},
#  541: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 22,
#   'min_samples_split': 0.16},
#  542: {'train': 0.7870582836163378,
#   'test': 0.7425424506654429,
#   'max_depth': 22,
#   'min_samples_split': 0.17},
#  543: {'train': 0.7845341899954107,
#   'test': 0.742083524552547,
#   'max_depth': 22,
#   'min_samples_split': 0.18000000000000002},
#  544: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 22,
#   'min_samples_split': 0.19},
#  545: {'train': 0.7845341899954107,
#   'test': 0.744837081229922,
#   'max_depth': 22,
#   'min_samples_split': 0.2},
#  546: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 22,
#   'min_samples_split': 0.21000000000000002},
#  547: {'train': 0.7737494263423589,
#   'test': 0.7333639284075264,
#   'max_depth': 22,
#   'min_samples_split': 0.22},
#  548: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 22,
#   'min_samples_split': 0.23},
#  549: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 22,
#   'min_samples_split': 0.24000000000000002},
#  550: {'train': 0.7592932537861404,
#   'test': 0.7255621844882973,
#   'max_depth': 22,
#   'min_samples_split': 0.25},
#  551: {'train': 0.8324919687930243,
#   'test': 0.7452960073428178,
#   'max_depth': 23,
#   'min_samples_split': 0.01},
#  552: {'train': 0.8141349242771914,
#   'test': 0.7508031206975677,
#   'max_depth': 23,
#   'min_samples_split': 0.02},
#  553: {'train': 0.8038090867370353,
#   'test': 0.7407067462138596,
#   'max_depth': 23,
#   'min_samples_split': 0.03},
#  554: {'train': 0.8010555300596603,
#   'test': 0.742083524552547,
#   'max_depth': 23,
#   'min_samples_split': 0.04},
#  555: {'train': 0.7978430472693896,
#   'test': 0.7430013767783387,
#   'max_depth': 23,
#   'min_samples_split': 0.05},
#  556: {'train': 0.7978430472693896,
#   'test': 0.7430013767783387,
#   'max_depth': 23,
#   'min_samples_split': 0.060000000000000005},
#  557: {'train': 0.79669573198715,
#   'test': 0.7425424506654429,
#   'max_depth': 23,
#   'min_samples_split': 0.06999999999999999},
#  558: {'train': 0.79669573198715,
#   'test': 0.7425424506654429,
#   'max_depth': 23,
#   'min_samples_split': 0.08},
#  559: {'train': 0.7953189536484626,
#   'test': 0.7434603028912345,
#   'max_depth': 23,
#   'min_samples_split': 0.09},
#  560: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 23,
#   'min_samples_split': 0.09999999999999999},
#  561: {'train': 0.791877007801744,
#   'test': 0.7439192290041303,
#   'max_depth': 23,
#   'min_samples_split': 0.11},
#  562: {'train': 0.7914180816888481,
#   'test': 0.7434603028912345,
#   'max_depth': 23,
#   'min_samples_split': 0.12},
#  563: {'train': 0.7914180816888481,
#   'test': 0.7434603028912345,
#   'max_depth': 23,
#   'min_samples_split': 0.13},
#  564: {'train': 0.7914180816888481,
#   'test': 0.7434603028912345,
#   'max_depth': 23,
#   'min_samples_split': 0.14},
#  565: {'train': 0.7877466727856816,
#   'test': 0.7425424506654429,
#   'max_depth': 23,
#   'min_samples_split': 0.15000000000000002},
#  566: {'train': 0.7877466727856816,
#   'test': 0.7425424506654429,
#   'max_depth': 23,
#   'min_samples_split': 0.16},
#  567: {'train': 0.7877466727856816,
#   'test': 0.7425424506654429,
#   'max_depth': 23,
#   'min_samples_split': 0.17},
#  568: {'train': 0.7852225791647545,
#   'test': 0.742083524552547,
#   'max_depth': 23,
#   'min_samples_split': 0.18000000000000002},
#  569: {'train': 0.7852225791647545,
#   'test': 0.744837081229922,
#   'max_depth': 23,
#   'min_samples_split': 0.19},
#  570: {'train': 0.7852225791647545,
#   'test': 0.744837081229922,
#   'max_depth': 23,
#   'min_samples_split': 0.2},
#  571: {'train': 0.7744378155117027,
#   'test': 0.7333639284075264,
#   'max_depth': 23,
#   'min_samples_split': 0.21000000000000002},
#  572: {'train': 0.7744378155117027,
#   'test': 0.7333639284075264,
#   'max_depth': 23,
#   'min_samples_split': 0.22},
#  573: {'train': 0.7599816429554842,
#   'test': 0.7255621844882973,
#   'max_depth': 23,
#   'min_samples_split': 0.23},
#  574: {'train': 0.7599816429554842,
#   'test': 0.7255621844882973,
#   'max_depth': 23,
#   'min_samples_split': 0.24000000000000002},
#  575: {'train': 0.7599816429554842,
#   'test': 0.7255621844882973,
#   'max_depth': 23,
#   'min_samples_split': 0.25},
#  576: {'train': 0.8343276732446077,
#   'test': 0.7452960073428178,
#   'max_depth': 24,
#   'min_samples_split': 0.01},
#  577: {'train': 0.8155117026158788,
#   'test': 0.7503441945846718,
#   'max_depth': 24,
#   'min_samples_split': 0.02},
#  578: {'train': 0.8051858650757228,
#   'test': 0.7397888939880679,
#   'max_depth': 24,
#   'min_samples_split': 0.03},
#  579: {'train': 0.8024323083983479,
#   'test': 0.742083524552547,
#   'max_depth': 24,
#   'min_samples_split': 0.04},
#  580: {'train': 0.7992198256080771,
#   'test': 0.7430013767783387,
#   'max_depth': 24,
#   'min_samples_split': 0.05},
#  581: {'train': 0.7992198256080771,
#   'test': 0.7430013767783387,
#   'max_depth': 24,
#   'min_samples_split': 0.060000000000000005},
#  582: {'train': 0.7980725103258376,
#   'test': 0.7425424506654429,
#   'max_depth': 24,
#   'min_samples_split': 0.06999999999999999},
#  583: {'train': 0.7980725103258376,
#   'test': 0.7425424506654429,
#   'max_depth': 24,
#   'min_samples_split': 0.08},
#  584: {'train': 0.79669573198715,
#   'test': 0.7434603028912345,
#   'max_depth': 24,
#   'min_samples_split': 0.09},
#  585: {'train': 0.7941716383662231,
#   'test': 0.7434603028912345,
#   'max_depth': 24,
#   'min_samples_split': 0.09999999999999999},
#  586: {'train': 0.7932537861404314,
#   'test': 0.7439192290041303,
#   'max_depth': 24,
#   'min_samples_split': 0.11},
#  587: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 24,
#   'min_samples_split': 0.12},
#  588: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 24,
#   'min_samples_split': 0.13},
#  589: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 24,
#   'min_samples_split': 0.14},
#  590: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 24,
#   'min_samples_split': 0.15000000000000002},
#  591: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 24,
#   'min_samples_split': 0.16},
#  592: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 24,
#   'min_samples_split': 0.17},
#  593: {'train': 0.7865993575034419,
#   'test': 0.742083524552547,
#   'max_depth': 24,
#   'min_samples_split': 0.18000000000000002},
#  594: {'train': 0.7865993575034419,
#   'test': 0.744837081229922,
#   'max_depth': 24,
#   'min_samples_split': 0.19},
#  595: {'train': 0.7865993575034419,
#   'test': 0.744837081229922,
#   'max_depth': 24,
#   'min_samples_split': 0.2},
#  596: {'train': 0.7758145938503901,
#   'test': 0.7333639284075264,
#   'max_depth': 24,
#   'min_samples_split': 0.21000000000000002},
#  597: {'train': 0.7758145938503901,
#   'test': 0.7333639284075264,
#   'max_depth': 24,
#   'min_samples_split': 0.22},
#  598: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 24,
#   'min_samples_split': 0.23},
#  599: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 24,
#   'min_samples_split': 0.24000000000000002},
#  600: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 24,
#   'min_samples_split': 0.25},
#  601: {'train': 0.8347865993575034,
#   'test': 0.7439192290041303,
#   'max_depth': 25,
#   'min_samples_split': 0.01},
#  602: {'train': 0.8155117026158788,
#   'test': 0.7503441945846718,
#   'max_depth': 25,
#   'min_samples_split': 0.02},
#  603: {'train': 0.8051858650757228,
#   'test': 0.7393299678751721,
#   'max_depth': 25,
#   'min_samples_split': 0.03},
#  604: {'train': 0.8024323083983479,
#   'test': 0.742083524552547,
#   'max_depth': 25,
#   'min_samples_split': 0.04},
#  605: {'train': 0.7992198256080771,
#   'test': 0.7430013767783387,
#   'max_depth': 25,
#   'min_samples_split': 0.05},
#  606: {'train': 0.7992198256080771,
#   'test': 0.7430013767783387,
#   'max_depth': 25,
#   'min_samples_split': 0.060000000000000005},
#  607: {'train': 0.7980725103258376,
#   'test': 0.7425424506654429,
#   'max_depth': 25,
#   'min_samples_split': 0.06999999999999999},
#  608: {'train': 0.7980725103258376,
#   'test': 0.7425424506654429,
#   'max_depth': 25,
#   'min_samples_split': 0.08},
#  609: {'train': 0.79669573198715,
#   'test': 0.7434603028912345,
#   'max_depth': 25,
#   'min_samples_split': 0.09},
#  610: {'train': 0.7941716383662231,
#   'test': 0.7434603028912345,
#   'max_depth': 25,
#   'min_samples_split': 0.09999999999999999},
#  611: {'train': 0.7932537861404314,
#   'test': 0.7439192290041303,
#   'max_depth': 25,
#   'min_samples_split': 0.11},
#  612: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 25,
#   'min_samples_split': 0.12},
#  613: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 25,
#   'min_samples_split': 0.13},
#  614: {'train': 0.7927948600275355,
#   'test': 0.7434603028912345,
#   'max_depth': 25,
#   'min_samples_split': 0.14},
#  615: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 25,
#   'min_samples_split': 0.15000000000000002},
#  616: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 25,
#   'min_samples_split': 0.16},
#  617: {'train': 0.789123451124369,
#   'test': 0.7425424506654429,
#   'max_depth': 25,
#   'min_samples_split': 0.17},
#  618: {'train': 0.7865993575034419,
#   'test': 0.742083524552547,
#   'max_depth': 25,
#   'min_samples_split': 0.18000000000000002},
#  619: {'train': 0.7865993575034419,
#   'test': 0.744837081229922,
#   'max_depth': 25,
#   'min_samples_split': 0.19},
#  620: {'train': 0.7865993575034419,
#   'test': 0.744837081229922,
#   'max_depth': 25,
#   'min_samples_split': 0.2},
#  621: {'train': 0.7758145938503901,
#   'test': 0.7333639284075264,
#   'max_depth': 25,
#   'min_samples_split': 0.21000000000000002},
#  622: {'train': 0.7758145938503901,
#   'test': 0.7333639284075264,
#   'max_depth': 25,
#   'min_samples_split': 0.22},
#  623: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 25,
#   'min_samples_split': 0.23},
#  624: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 25,
#   'min_samples_split': 0.24000000000000002},
#  625: {'train': 0.7613584212941716,
#   'test': 0.7255621844882973,
#   'max_depth': 25,
#   'min_samples_split': 0.25}}

# %%
tuning_table = pd.DataFrame.from_dict(tuning_dict)

# %%
tuning_table_t = tuning_table.transpose().sort_values("train", ascending=False)
md = tuning_table_t["max_depth"].iloc[0]
mss = tuning_table_t["min_samples_split"].iloc[0]
tuning_table.transpose()
# Out:
#         train      test  max_depth  min_samples_split
# 1    0.445158  0.459385        1.0               0.01
# 2    0.445158  0.459385        1.0               0.02
# 3    0.445158  0.459385        1.0               0.03
# 4    0.445158  0.459385        1.0               0.04
# 5    0.445158  0.459385        1.0               0.05
# ..        ...       ...        ...                ...
# 621  0.775815  0.733364       25.0               0.21
# 622  0.775815  0.733364       25.0               0.22
# 623  0.761358  0.725562       25.0               0.23
# 624  0.761358  0.725562       25.0               0.24
# 625  0.761358  0.725562       25.0               0.25
#
# [625 rows x 4 columns]

# %%
#optimized decision tree
dt = DecisionTreeClassifier(max_depth = md, min_samples_split = mss)

# %%
#final vector written here (no max number of features)
vector = tfidf(stop_words = "english", strip_accents = 'ascii', max_features = None)

#fit the tfidf on all the train data:
train_final = vector.fit_transform(train["text"])

#the final transformation and fitting before using the test data:
test_final = vector.transform(test["text"])

# %%
#fit model on FULL train data
dt.fit(train_final, train["label"])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=25,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.01,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
#score it on the test data
final_score = dt.score(test_final, test["label"])

#the final score
final_score
# Out:
# 0.8311926605504587

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
#get predictions from the decision tree
predictions = dt.predict(test_final)
predictions
# Out:
# array([0, 3, 1, ..., 2, 3, 3], dtype=int64)

# %%
# helper function defined
normed_cm(test["label"],predictions);
plt.title("Confusion Matrix Decision Tree");

# %% [markdown]
# # Modeling - K nearest neighbors
# Jenna
#
# Building a KNN Classifer model with the text data

# %% [markdown]
# ### Part 1: Scoring our words with TFIDFVectorizer

# %%
#basic tfidf vectorizer
vector = tfidf(stop_words = "english", strip_accents = 'ascii', max_features = 50)

#fit the data onto our vector
vector.fit(X_train)

# %%
#look at the vectorizer
print(vector.get_feature_names())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#transforming the data, manipulating it based on the weights we 
#determined before by fitting our data 
train_transformed = vector.transform(X_train)
test_transformed = vector.transform(X_test)

#splitting
train_test_split(train_transformed, Y_train)[0], train_test_split(train_transformed, Y_train)[1]

# %% [markdown]
# (<4902x50 sparse matrix of type '<class 'numpy.float64'>'
#  	with 48487 stored elements in Compressed Sparse Row format>,
#  <1635x50 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16097 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# ### Part 2: Hyperparameter Tuning and Cross Validation
#
# Finding the best k by performing cross validation

# %%
#Cross Validation for k

# creating odd list of k for KNN (to prevent ties)
neighbors = list(range(1, 50, 2))
# empty list that will hold cv scores
cv_scores = []


# perform 10-fold cross validation
for k in neighbors:
    knearest = knn(n_neighbors = k)
    scores = cross_val_score(knearest, train_transformed, Y_train, cv = 10, scoring='accuracy')
    cv_scores.append(scores.mean())
    
# plot of accuracies for different k 
plt.plot(neighbors, cv_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %% [markdown]
# ### Cross Validation Results
# ![image.png](attachment:image.png)
#
# - highest cross val score at around a little less than k = 40
# - higher k's --> underfit
# - lower k's --> overfit

# %% [markdown]
# ### More hyperparameter tuning: trying different k's

# %%
#Trying different k values - which produces highest score
knn_scores = []

for i in range(1, 50, 2):
    knearest = knn(n_neighbors = i)
    knearest.fit(train_transformed, Y_train)
    
    knn_scores.append(knearest.score(test_transformed, Y_test))

knn_scores

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
best_k = (knn_scores.index(max(knn_scores)) + 1) * 2 - 1
best_k

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part 3: Create the Model with chosen k

# %%
#final vector written here (no max number of features)
vector = tfidf(stop_words = "english", strip_accents = 'ascii', max_features = None)

#fit the tfidf on all the train data:
train_final = vector.fit_transform(train["text"])

#the final transformation and fitting before using the test data:
test_final = vector.transform(X_test)

# %%
#fit model on FULL train data
knearest.fit(train_final, train["label"])

#score it on the test data
final_score = knearest.score(test_final, Y_test)

#the final score
final_score
# Out:
# 0.8795107033639143

# %%
normed_cm(test["label"],predictions);
plt.title("Confusion Matrix KNN");

# %% [markdown]
# ## Implementing a Multinomial Naive Bayes Classification Model
# Shinu

# %%
lst_model = []
train_accuracy = []
test_accuracy = []

# %% [markdown]
# Since the Multinomial Naive Bayes Model works best with text data hence all other features such as followers and following were removed from the feature set. The only features used and worked best with the classifier are <b>text, tag and title</b>. <br>

# %% [markdown]
# With stopwords:

# %%
preprocess = ColumnTransformer(
    [('tags_tfidf', tfidf(ngram_range=([1, 1])), 'tags'),
         ('text_tfidf', tfidf(ngram_range=(1,1)), 'text'),
    ('title_tfidf', tfidf(ngram_range=(1,1)), 'title')])
model = make_pipeline(
    preprocess,
    MultinomialNB())
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_pred = model.predict(X_val)
lst_model.append(model)

train_rmse = accuracy_score(y_train_pred, y_train)
test_rmse = accuracy_score(y_pred, y_val)
train_accuracy.append(train_rmse)
test_accuracy.append(test_rmse)
print('Train accuracy: %.4f' % train_rmse)
print('Validation accuracy: %.4f' % test_rmse)
# Out:
# Train accuracy: 0.9578
# Validation accuracy: 0.9192

# %%
preprocess = ColumnTransformer(
    [('tags_tfidf', tfidf(ngram_range=([1, 1])), 'tags'),
         ('text_tfidf', tfidf(ngram_range=(1,2)), 'text'),
    ('title_tfidf', tfidf(ngram_range=(1,2)), 'title')])
model = make_pipeline(
    preprocess,
    MultinomialNB())
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_pred = model.predict(X_val)
lst_model.append(model)

train_rmse = accuracy_score(y_train_pred, y_train)
test_rmse = accuracy_score(y_pred, y_val)
train_accuracy.append(train_rmse)
test_accuracy.append(test_rmse)
print('Train accuracy: %.4f' % train_rmse)
print('Validation accuracy: %.4f' % test_rmse)
# Out:
# Train accuracy: 0.9565
# Validation accuracy: 0.8930

# %% [markdown]
# Without stopwords:

# %%
preprocess = ColumnTransformer(
    [('tags_tfidf', tfidf(ngram_range=([1, 1]),stop_words='english'), 'tags'),
         ('text_tfidf', tfidf(ngram_range=(1,1),stop_words='english'), 'text'),
    ('title_tfidf', tfidf(ngram_range=(1,1),stop_words='english'), 'title')])
model = make_pipeline(
    preprocess,
    MultinomialNB())
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_pred = model.predict(X_val)
lst_model.append(model)

train_rmse = accuracy_score(y_train_pred, y_train)
test_rmse = accuracy_score(y_pred, y_val)
train_accuracy.append(train_rmse)
test_accuracy.append(test_rmse)
print('Train accuracy: %.4f' % train_rmse)
print('Validation accuracy: %.4f' % test_rmse)
# Out:
# Train accuracy: 0.9664
# Validation accuracy: 0.9352

# %%
preprocess = ColumnTransformer(
    [('tags_tfidf', tfidf(ngram_range=([1, 1]),stop_words='english'), 'tags'),
         ('text_tfidf', tfidf(ngram_range=(1,2),stop_words='english'), 'text'),
    ('title_tfidf', tfidf(ngram_range=(1,2),stop_words='english'), 'title')])
model = make_pipeline(
    preprocess,
    MultinomialNB())
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
y_pred = model.predict(X_val)
lst_model.append(model)

train_rmse = accuracy_score(y_train_pred, y_train)
test_rmse = accuracy_score(y_pred, y_val)
train_accuracy.append(train_rmse)
test_accuracy.append(test_rmse)
print('Train accuracy: %.4f' % train_rmse)
print('Validation accuracy: %.4f' % test_rmse)
# Out:
# Train accuracy: 0.9731
# Validation accuracy: 0.9196

# %%
train_val = []
for i in range(len(train_accuracy)):
    temp = []
    if i==0 or i==1:
        temp.append('include stop-words')
    if i==2 or i==3:
        temp.append('remove stop-words')
    if i==0 or i==2:
        temp.append('unigrams')
    if i==1 or i==3:
        temp.append('unigrams and bigrams')
    temp.append(train_accuracy[i])
    temp.append(test_accuracy[i])
    train_val.append(temp)
compiled_models = pd.DataFrame(train_val, columns=['Stop-Words','Unigrams/Bigrams','Train Accuracy','Validation Accuracy'])

# %% [markdown]
# The model was further optimised by playing with ngrams when converting text, tag and title to tfidf.<br>
# The best combination of ngrams was unigrams for tags, text and title. Converting the tfidf to either unigrams or bigrams for any of the features resulted in the training data to be overfit, hence, the validation score would drop.

# %%
compiled_models
# Out:
#            Stop-Words      Unigrams/Bigrams  Train Accuracy  \
# 0  include stop-words              unigrams        0.957761
# 1  include stop-words  unigrams and bigrams        0.956531
# 2   remove stop-words              unigrams        0.966373
# 3   remove stop-words  unigrams and bigrams        0.973139
#
#    Validation Accuracy
# 0             0.919229
# 1             0.892989
# 2             0.935219
# 3             0.919639

# %% [raw]
# The test score for the best model:

# %%
y_test_pred = lst_model[2].predict(X_test)
print('Test accuracy: %.4f' % accuracy_score(y_test_pred, y_test))
# Out:
# Test accuracy: 0.9381

# %%
C = confusion_matrix(y_test, y_test_pred)
C = C / C.astype(np.float).sum(axis=1)
classes = ['tech', 'sports','money','politics']
df_confusion = pd.DataFrame(C, columns=classes, index=classes)
import matplotlib.pyplot as plt
def plot_confusion_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
    plt.matshow(df_confusion, cmap=cmap) # imshow
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(df_confusion.columns))
    plt.xticks(tick_marks, df_confusion.columns, rotation=45)
    plt.yticks(tick_marks, df_confusion.index)
    #plt.tight_layout()
    plt.ylabel(df_confusion.index.name)
    plt.xlabel(df_confusion.columns.name)

plot_confusion_matrix(df_confusion)

# %% [markdown]
# # What Did We Learn?
# <img src = 'think.png' Think>

# %% [markdown]
# # What We learned
# - Webscraping with BeautifulSoup
# - ML Algorithms: KNN, decision trees
# - NLP: tfidf
# - Process of a data science project: getting data --> model building

# %% [markdown]
# # Future Direction
# <img src = 'keywords.png'>

# %% [markdown]
# # References:
# - Medium: https://medium.com/
# - Scikit-learn: Machine Learning in Python, Pedregosa et al., JMLR 12, pp. 2825-2830, 2011.
# - NLTK package: Bird, Steven, Edward Loper and Ewan Klein (2009), Natural Language Processing with Python. O’Reilly Media Inc.
# - https://stackabuse.com/overview-of-classification-methods-in-python-with-scikit-learn/
# - https://www.geeksforgeeks.org/elbow-method-for-optimal-value-of-k-in-kmeans/
# - https://blog.floydhub.com/gentle-introduction-to-text-summarization-in-machine-learning/
# - https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/
# - https://moz.com/learn/seo/robotstxt
#
# A special thanks to Ahan for his guidance throughout the quarter.

# %% [markdown]
# # Thank you!
